# %% [markdown]
# ### INTRODUCTION
#
# In this notebook, you will find a function that takes your resume and any job description you choose as a plain text file (.txt) as the input and gives a data frame with the word recommendations to add your resume based on the job description as the output by using some basic natural language processing methods.

# %%
# Import libraries and modules
import pandas as pd
import nltk
from nltk.corpus import stopwords
import re
import string
wn = nltk.WordNetLemmatizer() #Lemmatizer
stopword = nltk.corpus.stopwords.words('english') #Stopwords in English language

# %%
def matching_keywords(job_posting, resume):

    
    def clean_the_text(text):
        """
        Function to clean and tokenize the text.
        Input: 
            job_posting: text file
            resume: text_file
        Output: 
            text: cleaned and tekenized body of text        
        """
        
        #Replace non-word characters with empty space
        text = re.sub('[^A-Za-z0-9\s]', ' ', text)
        
        #Remove punctuation
        text = ''.join([word for word in text if word not in string.punctuation])
        
        #Bring text to lower case
        text = text.lower()
        
        #Tokenize the text
        tokens = re.split('\W+', text)
        
        #Remove stopwords
        text = [word for word in tokens if word not in stopword]
        
        #Lemmatize the words
        text = [wn.lemmatize(word) for word in text]
        
        #Return text
        return text
    
    #Read the files
    with open(job_posting, 'r') as f: 
        job_posting = f.read()

    with open(resume, 'r') as f:  
        resume = f.read()
        
        
    #Apply clean_the_text function to the text files   
    list_1 = clean_the_text(job_posting)
    list_2 = clean_the_text(resume)
    
    
    def common_words(l_1, l_2):
        """
        Input: 
            l_1: list of words
            l_2: list_of words
        Output: 
            matching_words: set of common words exist in l_1 and l_2        
        """
        matching_words = set.intersection(set(l_1), set(l_2))
        return matching_words
    
    #Apply common_words function to the lists
    common_keywords = common_words(list_1, list_2)
    
    #Print number of matching words
    print('The number of common words in your resume and the job posting is: {}'.format(len(common_keywords)),'\n')
    
    #Print the percentage of matching words
    print('{:.0%} of the words in your resume are in the job description'.format(len(common_keywords)/len(list_2)), '\n')    
    
    # Create an empty dictionary
    freq_table = {}
    
    # Create frequency table for the words that are not in the list_2 but in the list_1
    for word in list_1:
        if not word in list_2:
            if word in freq_table:
                freq_table[word] += 1
            else:
                freq_table[word] = 1
    
    # Sort the dictionary by values in descending order
    freq_table = dict(sorted(freq_table.items(), key=lambda item: item[1], reverse=True))
    
    # Create a pandas dataframe from the dictionary
    pd.set_option('display.max_rows', 300)
    df = pd.DataFrame.from_dict(freq_table.items())
    
    # Rename columns
    df.columns = ['word','count']
    
    print('You can choose some words in the job posting from the table below to add your resume.')
    return df

# %%
matching_keywords('data/job_posting.txt', 'data/Resume.txt')
# Out:
# The number of common words in your resume and the job posting is: 40
#
# 10% of the words in your resume are in the job description
#
# You can choose some words in the job posting from the table below to add your resume.
#                word  count
# 0            search     11
# 1              bing      7
# 2        enterprise      7
# 3              team      4
# 4       information      4
# 5             topic      4
# 6          language      3
# 7       opportunity      3
# 8           related      3
# 9          computer      3
# 10             year      3
# 11       employment      3
# 12            scale      2
# 13          natural      2
# 14       processing      2
# 15           people      2
# 16             time      2
# 17              web      2
# 18          content      2
# 19             user      2
# 20          explore      2
# 21        preferred      2
# 22                2      2
# 23            least      2
# 24              one      2
# 25                c      2
# 26        qualified      2
# 27        applicant      2
# 28          medical      2
# 29           status      2
# 30       disability      2
# 31        protected      2
# 32    accommodation      2
# 33          request      2
# 34          looking      1
# 35               ii      1
# 36         exciting      1
# 37            space      1
# 38            large      1
# 39      transformer      1
# 40              ner      1
# 41           mining      1
# 42             role      1
# 43         provides      1
# 44         research      1
# 45            apply      1
# 46            state      1
# 47              art      1
# 48             mine      1
# 49         valuable      1
# 50      discovering      1
# 51         creating      1
# 52             page      1
# 53            given      1
# 54          company      1
# 55         document      1
# 56       definition      1
# 57           expert      1
# 58              new      1
# 59         offering      1
# 60             save      1
# 61         bringing      1
# 62           single      1
# 63          evolved      1
# 64    significantly      1
# 65             last      1
# 66           decade      1
# 67         continue      1
# 68              use      1
# 69       antiquated      1
# 70    strategically      1
# 71       positioned      1
# 72            solve      1
# 73          problem      1
# 74           access      1
# 75             m365      1
# 76        expertise      1
# 77          mission      1
# 78             make      1
# 79             easy      1
# 80         discover      1
# 81          variety      1
# 82           source      1
# 83       leveraging      1
# 84         existing      1
# 85            habit      1
# 86        searching      1
# 87          browser      1
# 88          address      1
# 89              bar      1
# 90        resulting      1
# 91         improved      1
# 92     productivity      1
# 93             take      1
# 94            power      1
# 95        upholding      1
# 96          privacy      1
# 97          promise      1
# 98          closely      1
# 99            s2500      1
# 100         serving      1
# 101             ten      1
# 102         million      1
# 103            plan      1
# 104            grow      1
# 105       multifold      1
# 106            near      1
# 107          future      1
# 108             see      1
# 109            http      1
# 110             www      1
# 111        business      1
# 112  responsibility      1
# 113          design      1
# 114       prototype      1
# 115       implement      1
# 116       architect      1
# 117         develop      1
# 118     operational      1
# 119             run      1
# 120         partner      1
# 121         product      1
# 122     improvement      1
# 123         provide      1
# 124      leadership      1
# 125       proposing      1
# 126         guiding      1
# 127          junior      1
# 128       reviewing      1
# 129      experiment      1
# 130   qualification      1
# 131               b      1
# 132               m      1
# 133          physic      1
# 134      discipline      1
# 135             phd      1
# 136               3      1
# 137            deep      1
# 138       framework      1
# 139         pytorch      1
# 140             etc      1
# 141     programming      1
# 142               r      1
# 143            java      1
# 144       excellent      1
# 145   communication      1
# 146   collaborative      1
# 147            plus      1
# 148           equal      1
# 149        employer      1
# 150         receive      1
# 151   consideration      1
# 152         without      1
# 153          regard      1
# 154             age      1
# 155        ancestry      1
# 156           color      1
# 157          family      1
# 158            care      1
# 159           leave      1
# 160          gender      1
# 161        identity      1
# 162      expression      1
# 163         genetic      1
# 164         marital      1
# 165       condition      1
# 166        national      1
# 167          origin      1
# 168          mental      1
# 169       political      1
# 170     affiliation      1
# 171         veteran      1
# 172            race      1
# 173        religion      1
# 174             sex      1
# 175       including      1
# 176       pregnancy      1
# 177          sexual      1
# 178     orientation      1
# 179  characteristic      1
# 180      applicable      1
# 181             law      1
# 182      regulation      1
# 183       ordinance      1
# 184            also      1
# 185        consider      1
# 186      regardless      1
# 187        criminal      1
# 188         history      1
# 189      consistent      1
# 190           legal      1
# 191     requirement      1
# 192            need      1
# 193      assistance      1
# 194      reasonable      1
# 195             due      1
# 196      recruiting      1
# 197         process      1
# 198          please      1
# 199            send      1
# 200             via      1
# 201            form      1
# 202         benefit      1
# 203            perk      1
# 204          listed      1
# 205            vary      1
# 206       depending      1
# 207          nature      1
# 208        industry      1
# 209        hardware      1
# 210        software      1
# 211            full      1
# 212             job      1
# 213        function      1

# %% [markdown]
# ### CONCLUSION
#
# By using this function, you can tailor your resume based on the job description and enhance the visibility of your resume in applicant tracking systems (ATS) when you apply for a job online.
